# %% [markdown]
# <a href="https://colab.research.google.com/github/castrigno22/geopandas/blob/main/correzioneVerificaFila_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client["4E"]

# %% [markdown]
# 1)il cognome e il nome dei capomissione con la loro funzione

# %%
result = db.consolati.find({},{"capomissione":1,"funzionecapo":1,"_id":0})
df = pd.DataFrame(list(result))
df
# Out:
#                capomissione                 funzionecapo
# 0              PALA MICHELE             CONSOLE GENERALE
# 1         OCCHIPINTI NICOLA             CONSOLE GENERALE
# 2          DE RIU ANTONELLO             CONSOLE GENERALE
# 3         LA PIANA ANTONINO  CONSOLE GENERALE (Reggente)
# 4          BENCINI LEONARDO             CONSOLE GENERALE
# ..                      ...                          ...
# 446    BELLA GIANLUCA MARIA    Agente consolare onorario
# 447      CASSINA ITALO JUAN    Agente consolare onorario
# 448  INFANTI PAMELA BEATRIZ    Agente consolare onorario
# 449    KOKKINAKIS DIMITRIOS    Agente consolare onorario
# 450      AARSETH NILS HELGE    Agente consolare onorario
#
# [451 rows x 2 columns]

# %% [markdown]
# 2)l’indirizzo del consolato di Zurig

# %%
result = db.consolati.find({"indirizzo":{"$regex":"Zurigo"}},{"indirizzo":1,"_id":0})
df = pd.DataFrame(list(result))
df
# Out:
#                        indirizzo
# 0  Tödistrasse, 65 - 8002 Zurigo

# %% [markdown]
# 3)l’elenco dei consolati generali. Ordinare in ordine alfabetico

# %%
result = db.consolati.find({"sede":{"$regex":"CONSOLATO GENERALE"}},{"sede":1,"_id":0,}).sort("sede", 1)
df = pd.DataFrame(list(result))
df
# Out:
#                                                  sede
# 0    CONSOLATO GENERALE - BAHIA BLANCA (Buenos Aires)
# 1                     CONSOLATO GENERALE - BARCELLONA
# 2                        CONSOLATO GENERALE - BENGASI
# 3         CONSOLATO GENERALE - BOSTON (Massachusetts)
# 4                   CONSOLATO GENERALE - BUENOS AIRES
# ..                                                ...
# 66               CONSOLATO GENERALE ONORARIO - NASSAU
# 67       CONSOLATO GENERALE ONORARIO - PORT AU PRINCE
# 68  CONSOLATO GENERALE ONORARIO - REYKJAVIK - HAFN...
# 69          CONSOLATO GENERALE ONORARIO - TEGUCIGALPA
# 70             CONSOLATO GENERALE ONORARIO - WINDHOEK
#
# [71 rows x 1 columns]

# %% [markdown]
# 4)il numero complessivo di consoli generali

# %%
result = db.consolati.count_documents({"funzionecapo":"CONSOLATO GENERALE"})
df = pd.DataFrame(list(result))
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3cf87076b7a7> in <module>()
#       1 result = db.consolati.count_documents({"funzionecapo":"CONSOLATO GENERALE"})
# ----> 2 df = pd.DataFrame(list(result))
#       3 df
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# 5)i consolati che si trovano nell’emisfero australe

# %%
result = db.consolati.find({"lat":{"$lt":0}},{"sede":1,"_id":0})
df = pd.DataFrame(list(result))
df
# Out:
#                                                  sede
# 0      CONSOLATO GENERALE DI PRIMA CLASSE - SAN PAOLO
# 1   CONSOLATO GENERALE - PORTO ALEGRE (Rio Grande ...
# 2                   CONSOLATO GENERALE - BUENOS AIRES
# 3    CONSOLATO GENERALE - BAHIA BLANCA (Buenos Aires)
# 4                        CONSOLATO GENERALE - CORDOBA
# ..                                                ...
# 85             AGENZIA CONSOLARE ONORARIA - RIO CLARO
# 86         AGENZIA CONSOLARE ONORARIA - PUERTO MADRYN
# 87          AGENZIA CONSOLARE ONORARIA - CHRISTCHURCH
# 88  AGENZIA CONSOLARE ONORARIA - RIO CUARTO (Cordoba)
# 89  AGENZIA CONSOLARE ONORARIA - TANDIL (Buenos Ai...
#
# [90 rows x 1 columns]

# %% [markdown]
# 6)l’elenco dei consolati presenti in Argentina

# %%
result = db.consolati.find({"paese":"ARGENTINA"},{"sede":1,"_id":0})
df = pd.DataFrame(list(result))
df
# Out:
#                                                  sede
# 0                   CONSOLATO GENERALE - BUENOS AIRES
# 1    CONSOLATO GENERALE - BAHIA BLANCA (Buenos Aires)
# 2                        CONSOLATO GENERALE - CORDOBA
# 3             CONSOLATO GENERALE - ROSARIO (Santa Fè)
# 4        CONSOLATO GENERALE - LA PLATA (Buenos Aires)
# 5                 CONSOLATO DI PRIMA CLASSE - MENDOZA
# 6                           CONSOLATO - MAR DEL PLATA
# 7            AGENZIA CONSOLARE - MORON (Buenos Aires)
# 8   AGENZIA CONSOLARE - LOMAS DE ZAMORA (Buenos Ai...
# 9        VICE CONSOLATO ONORARIO - POSADAS (Misiones)
# 10      VICE CONSOLATO ONORARIO - SANTIAGO DEL ESTERO
# 11                  VICE CONSOLATO ONORARIO - FORMOSA
# 12  VICE CONSOLATO ONORARIO - SAN ISIDRO (Buenos A...
# 13    VICE CONSOLATO ONORARIO - SAN SALVADOR DE JUJUY
# 14                    VICE CONSOLATO ONORARIO - SALTA
# 15       VICE CONSOLATO ONORARIO - SANTA ROSA DE TOAY
# ...

# %% [markdown]
# 7)l’elenco dei consolati presenti in Argentina e in Brasile

# %%
result = db.consolati.find({"$or":[{"paese":"ARGENTINA"},{"paese":"BRASILE"}]},{"sede":1,"_id":0})
df = pd.DataFrame(list(result))
df
# Out:
#                                                  sede
# 0      CONSOLATO GENERALE DI PRIMA CLASSE - SAN PAOLO
# 1   CONSOLATO GENERALE - PORTO ALEGRE (Rio Grande ...
# 2                   CONSOLATO GENERALE - BUENOS AIRES
# 3    CONSOLATO GENERALE - BAHIA BLANCA (Buenos Aires)
# 4                        CONSOLATO GENERALE - CORDOBA
# ..                                                ...
# 75             AGENZIA CONSOLARE ONORARIA - RIO CLARO
# 76         AGENZIA CONSOLARE ONORARIA - PUERTO MADRYN
# 77           AGENZIA CONSOLARE ONORARIA - VILLA MARIA
# 78  AGENZIA CONSOLARE ONORARIA - RIO CUARTO (Cordoba)
# 79  AGENZIA CONSOLARE ONORARIA - TANDIL (Buenos Ai...
#
# [80 rows x 1 columns]

# %% [markdown]
# 8)i consolati di cui non si conosce il sito web

# %%
result = db.consolati.find({"sitoweb" : None})
df = pd.DataFrame(list(result))
df
# Out:
#                           _id  \
# 0    623ca2f7f224e8f68db4a9b5
# 1    623ca2f7f224e8f68db4a9b6
# 2    623ca2f7f224e8f68db4a9b8
# 3    623ca2f7f224e8f68db4a9b9
# 4    623ca2f7f224e8f68db4a9ba
# ..                        ...
# 345  623ca2f7f224e8f68db4ab23
# 346  623ca2f7f224e8f68db4ab24
# 347  623ca2f7f224e8f68db4ab25
# 348  623ca2f7f224e8f68db4ab26
# 349  623ca2f7f224e8f68db4ab27
#
#                                                   sede  idtiposede  \
# 0    CONSOLATO GENERALE ONORARIO - REYKJAVIK - HAFN...           9
# 1         CONSOLATO GENERALE ONORARIO - PORT AU PRINCE           9
# 2               CONSOLATO GENERALE ONORARIO - WINDHOEK           9
# 3              CONSOLATO GENERALE ONORARIO - KATHMANDU           9
# 4      CONSOLATO GENERALE ONORARIO - ATLANTA (Georgia)           9
# ..                                                 ...         ...
# 345  AGENZIA CONSOLARE ONORARIA - RIO CUARTO (Cordoba)          12
# ...

# %% [markdown]
# 9)i consolati che non hanno una mail del Ministero degli Esteri

# %%
result = db.consolati.find({"email" :{"$not" :{"$regex" : "@esteri.it"}}})
df = pd.DataFrame(list(result))
df
# Out:
#                           _id  \
# 0    623ca2f7f224e8f68db4a9b5
# 1    623ca2f7f224e8f68db4a9b6
# 2    623ca2f7f224e8f68db4a9b7
# 3    623ca2f7f224e8f68db4a9b8
# 4    623ca2f7f224e8f68db4a9ba
# ..                        ...
# 241  623ca2f7f224e8f68db4ab22
# 242  623ca2f7f224e8f68db4ab23
# 243  623ca2f7f224e8f68db4ab25
# 244  623ca2f7f224e8f68db4ab26
# 245  623ca2f7f224e8f68db4ab27
#
#                                                   sede  idtiposede  \
# 0    CONSOLATO GENERALE ONORARIO - REYKJAVIK - HAFN...           9
# 1         CONSOLATO GENERALE ONORARIO - PORT AU PRINCE           9
# 2                 CONSOLATO GENERALE ONORARIO - GIBUTI           9
# 3               CONSOLATO GENERALE ONORARIO - WINDHOEK           9
# 4      CONSOLATO GENERALE ONORARIO - ATLANTA (Georgia)           9
# ..                                                 ...         ...
# 241              AGENZIA CONSOLARE ONORARIA - GUERNSEY          12
# ...

# %% [markdown]
# 10)il numero di consolati in ogni continente

# %%
result = db.consolati.aggregate([{"$group" :{"_id":"$continente", "total" : {"$sum" : 1}}},
                                 {"$sort" :{"_id" : 1}}])
df = pd.DataFrame(list(result))
df
# Out:
#                 _id  total
# 0            Africa     31
# 1              Asia     49
# 2            Europe    160
# 3  Northern America     63
# 4           Oceania     15
# 5     South America    133

# %% [markdown]
# 11)i continenti che hanno più di 50 consolati. Ordinare in ordine decrescente a partire dal continente che ha più consolati

# %%
result = db.consolati.aggregate([
                                 {"$group" :{"_id":"$continente", "total" : {"$sum" : 1}}},
                                 {"$match" :{"total":{"$gt":50}}},
                                 {"$sort" :{"total" : -1}}])
df = pd.DataFrame(list(result))
df
# Out:
#                 _id  total
# 0            Europe    160
# 1     South America    133
# 2  Northern America     63

# %% [markdown]
# 12)il paese che ha più consolati
